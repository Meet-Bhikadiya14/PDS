# %% [markdown]
# # Practical 1
# ### Aim
# To write Python programs to demonstrate variables, basic data types and different types of operators.

# %% [markdown]
# ### 1. Variables and Data Types

# %%
name = "Meet"
roll_no = 18
age = 21
marks = 65
student = True

print(name)
print(roll_no)
print(age)
print(marks)
print(student)

print(type(name))
print(type(roll_no))
print(type(age))
print(type(marks))
print(type(student))
# Out:
# Meet
# 18
# 21
# 65
# True
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>

# %% [markdown]
# ### 2. Arithmetic Operators

# %%
a = 20
b = 6

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** 2)
# Out:
# 26
# 14
# 120
# 3.3333333333333335
# 3
# 2
# 400

# %% [markdown]
# ### 3. Assignment Operators

# %%
a = 10
print(a)

a += 5
print(a)

a -= 2
print(a)

a *= 2
print(a)

a /= 2
print(a)

a //= 2
print(a)

a %= 3
print(a)
# Out:
# 10
# 15
# 13
# 26
# 13.0
# 6.0
# 0.0

# %% [markdown]
# ### 4. Comparison Operators

# %%
a = 10
b = 20

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# ### 5. Logical Operators

# %%
a = 10
b = 20

print(a > 5 and b > 15)
print(a > 15 or b > 15)
print(not(a > 15))
# Out:
# True
# True
# True

# %% [markdown]
# ### 6. Membership Operators

# %%
name = "Meet"
numbers = [10, 20, 30, 40]

print("A" in name)
print("z" not in name)
print(20 in numbers)
print(50 not in numbers)
# Out:
# False
# True
# True
# True

# %% [markdown]
# ### 7. Identity Operators

# %%
a = [1, 2, 3]
b = a
c = [1, 2, 3]

print(a is b)
print(a is c)
print(a is not c)
# Out:
# True
# False
# True

# %% [markdown]
# ### 8. Bitwise Operators

# %%
a = 10
b = 6

print(a & b)
print(a | b)
print(a ^ b)
print(~a)
print(a << 1)
print(a >> 1)
# Out:
# 2
# 14
# 12
# -11
# 20
# 5
