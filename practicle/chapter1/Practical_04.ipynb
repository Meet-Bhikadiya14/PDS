# %% [markdown]
# # Practical 4
# ### Aim
# To write Python programs using user-defined functions with different argument and return types and to demonstrate the use of math, random and statistics modules.

# %% [markdown]
# ### 1. Parameter with No Return

# %%
def student(name, age):
    print("Name:", name)
    print("Age:", age)

student("Meet", 21)
# Out:
# Name: Meet
# Age: 21

# %% [markdown]
# ### 2. Parameter with Return

# %%
def add(a, b):
    return a + b

x = add(10, 20)
print(x)
# Out:
# 30

# %% [markdown]
# ### 3. No Parameter with Return

# %%
def get_number():
    a = 41
    return a

x = get_number()
print(x)
# Out:
# 41

# %% [markdown]
# ### 4. No Parameter with No Return

# %%
def message():
    print("Python for Data Science")

message()
# Out:
# Python for Data Science

# %% [markdown]
# ### 5. Function with Two Return Values

# %%
def calculate(a, b):
    add = a + b
    multiply = a * b
    return add, multiply

x, y = calculate(10, 5)
print(x)
print(y)
# Out:
# 15
# 50

# %% [markdown]
# ### 6. math Module

# %%
import math

print(math.sqrt(25))
print(math.pow(2, 3))
print(math.factorial(5))
print(math.ceil(4.2))
print(math.floor(4.8))
print(math.pi)
# Out:
# 5.0
# 8.0
# 120
# 5
# 4
# 3.141592653589793

# %% [markdown]
# ### 7. random Module

# %%
import random

print(random.randint(1, 10))
print(random.randrange(1, 20))

a = [10, 20, 30, 40, 50]
print(random.choice(a))

random.shuffle(a)
print(a)
# Out:
# 9
# 8
# 40
# [30, 40, 10, 20, 50]

# %% [markdown]
# ### 8. statistics Module

# %%
import statistics

marks = [70, 80, 90, 75, 85, 80]

print(statistics.mean(marks))
print(statistics.median(marks))
print(statistics.mode(marks))
print(statistics.variance(marks))
print(statistics.stdev(marks))
# Out:
# 80
# 80.0
# 80
# 50
# 7.0710678118654755
