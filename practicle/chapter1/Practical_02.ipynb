# %% [markdown]
# # Practical 2
# ### Aim
# To demonstrate creation and manipulation of list, tuple, set, dictionary and string using their built-in methods.

# %% [markdown]
# ### 1. List

# %%
friends = ["Ashish", "Harsh", "Taksh", "Aryan"]
print(friends)
print(friends[0])
print(friends[-1])

friends.append("Adi")
print(friends)
friends.insert(1, "Darsh")
print(friends)
friends.remove("Adi")
print(friends)
x = friends.pop()
print(x)
print(friends)
friends.sort()
print(friends)
friends.reverse()
print(friends)
print(len(friends))
print(friends.count("Darsh"))
print(friends.index("Ashish"))
# Out:
# ['Ashish', 'Harsh', 'Taksh', 'Aryan']
# Ashish
# Aryan
# ['Ashish', 'Harsh', 'Taksh', 'Aryan', 'Adi']
# ['Ashish', 'Darsh', 'Harsh', 'Taksh', 'Aryan', 'Adi']
# ['Ashish', 'Darsh', 'Harsh', 'Taksh', 'Aryan']
# Aryan
# ['Ashish', 'Darsh', 'Harsh', 'Taksh']
# ['Ashish', 'Darsh', 'Harsh', 'Taksh']
# ['Taksh', 'Harsh', 'Darsh', 'Ashish']
# 4
# 1
# 3

# %% [markdown]
# ### 2. Tuple

# %%
subjects = ("Python", "CN", "MPI", "PDS", "PM")
print(subjects)
print(subjects[0])
print(subjects[-1])
print(len(subjects))
print(subjects.count("Python"))
print(subjects.index("PDS"))
print(subjects[1:4])
# Out:
# ('Python', 'CN', 'MPI', 'PDS', 'PM')
# Python
# PM
# 5
# 1
# 3
# ('CN', 'MPI', 'PDS')

# %% [markdown]
# ### 3. Set

# %%
numbers = {10, 20, 30, 40, 20}
print(numbers)
numbers.add(50)
print(numbers)
numbers.update([60, 70])
print(numbers)
numbers.remove(30)
print(numbers)
numbers.discard(100)
print(numbers)
a = {1, 2, 3, 4}
b = {3, 4, 5, 6}
print(a.union(b))
print(a.intersection(b))
print(a.difference(b))
print(a.symmetric_difference(b))
# Out:
# {40, 10, 20, 30}
# {40, 10, 50, 20, 30}
# {70, 40, 10, 50, 20, 60, 30}
# {70, 40, 10, 50, 20, 60}
# {70, 40, 10, 50, 20, 60}
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
# {1, 2, 5, 6}

# %% [markdown]
# ### 4. Dictionary

# %%
student = {"name": "meet", "roll_no": 18, "age": 21, "course": "Computer Engineering"}
print(student)
print(student["name"])
print(student.get("age"))
student["city"] = "Surat"
print(student)
student["age"] = 22
print(student)
student.pop("city")
print(student)
print(student.keys())
print(student.values())
print(student.items())
student.update({"age": 21, "marks": 65})
print(student)
# Out:
# {'name': 'meet', 'roll_no': 18, 'age': 21, 'course': 'Computer Engineering'}
# meet
# 21
# {'name': 'meet', 'roll_no': 18, 'age': 21, 'course': 'Computer Engineering', 'city': 'Surat'}
# {'name': 'meet', 'roll_no': 18, 'age': 22, 'course': 'Computer Engineering', 'city': 'Surat'}
# {'name': 'meet', 'roll_no': 18, 'age': 22, 'course': 'Computer Engineering'}
# dict_keys(['name', 'roll_no', 'age', 'course'])
# dict_values(['meet', 18, 22, 'Computer Engineering'])
# dict_items([('name', 'meet'), ('roll_no', 18), ('age', 22), ('course', 'Computer Engineering')])
# {'name': 'meet', 'roll_no': 18, 'age': 21, 'course': 'Computer Engineering', 'marks': 65}

# %% [markdown]
# ### 5. String

# %%
text = "Python for Data Science"
print(text)
print(len(text))
print(text[0])
print(text[0:6])
print(text.upper())
print(text.lower())
print(text.title())
print(text.capitalize())
print(text.replace("Python", "Python Programming"))
print(text.find("Data"))
print(text.count("o"))
print(text.startswith("Python"))
print(text.endswith("Science"))
a = "  hello  "
print(a.strip())
print(a.lstrip())
print(a.rstrip())
words = text.split(" ")
print(words)
print("-".join(words))
# Out:
# Python for Data Science
# 23
# P
# Python
# PYTHON FOR DATA SCIENCE
# python for data science
# Python For Data Science
# Python for data science
# Python Programming for Data Science
# 11
# 2
# True
# True
# hello
# hello
#   hello
# ['Python', 'for', 'Data', 'Science']
# Python-for-Data-Science
