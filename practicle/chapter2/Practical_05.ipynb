# %% [markdown]
# # Practical 5
# ### Aim
# To perform read, write and append operations on text files, CSV files and binary files using Python.

# %% [markdown]
# ### 1. Text File - Write

# %%
f = open("abc.txt", "w")
f.write("Name: Meet\n")
f.write("Roll No: 18\n")
f.write("Age: 21\n")
f.close()

print("Data written")
# Out:
# Data written

# %% [markdown]
# ### 2. Text File - Read

# %%
f = open("abc.txt", "r")
data = f.read()
f.close()

print(data)
# Out:
# Name: Meet
# Roll No: 18
# Age: 21
# This is appended data.
# Python for Data Science

# %% [markdown]
# ### 3. Text File - Append

# %%
f = open("abc.txt", "a")
f.write("This is appended data.\n")
f.write("Python for Data Science\n")
f.close()

print("Data appended")
# Out:
# Data appended

# %% [markdown]
# ### 4. Read Appended Text File

# %%
f = open("abc.txt", "r")
print(f.read())
f.close()
# Out:
# Name: Meet
# Roll No: 18
# Age: 21
# This is appended data.
# Python for Data Science

# %% [markdown]
# ### 5. CSV File - Write

# %%
import csv

f = open("abc.csv", "w", newline="")
writer = csv.writer(f)

writer.writerow(["Name", "Roll No", "Age"])
writer.writerow(["Meet", 18, 21])
writer.writerow(["Divy", 19, 21])
writer.writerow(["Prince", 20, 22])

f.close()

print("CSV file created")
# Out:
# CSV file created

# %% [markdown]
# ### 6. CSV File - Read

# %%
f = open("abc.csv", "r")
reader = csv.reader(f)

for row in reader:
    print(row)

f.close()
# Out:
# ['Name', 'Roll No', 'Age']
# ['Meet', '18', '21']
# ['Divy', '19', '21']
# ['Prince', '20', '22']

# %% [markdown]
# ### 7. CSV File - Append

# %%
f = open("abc.csv", "a", newline="")
writer = csv.writer(f)
writer.writerow(["Jay", 44, 20])
f.close()

print("Data appended to CSV")
# Out:
# Data appended to CSV

# %% [markdown]
# ### 8. Read CSV After Append

# %%
f = open("abc.csv", "r")
reader = csv.reader(f)

for row in reader:
    print(row)

f.close()
# Out:
# ['Name', 'Roll No', 'Age']
# ['Meet', '18', '21']
# ['Divy', '19', '21']
# ['Prince', '20', '22']
# ['Jay', '44', '20']

# %% [markdown]
# ### 9. Binary File - Write

# %%
f = open("abc.bin", "wb")
data =b"Hello Ashish"
f.write(data)
f.close()

print("Binary data written")
# Out:
# Binary data written

# %% [markdown]
# ### 10. Binary File - Read

# %%
f = open("abc.bin", "rb")
data = f.read()
f.close()

print(data)
# Out:
# b'Hello Meet'

# %% [markdown]
# ### 11. Binary File - Append

# %%
f = open("abc.bin", "ab")
f.write(b" Python")
f.close()

print("Binary data appended")
# Out:
# Binary data appended

# %% [markdown]
# ### 12. Read Binary File After Append

# %%
f = open("abc.bin", "rb")
data = f.read()
f.close()

print(data)
# Out:
# b'Hello Meet Python'
