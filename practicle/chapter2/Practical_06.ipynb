# %% [markdown]
# # Practical 6
# ### Aim
# To demonstrate exception handling using try, except, else, finally blocks and raise statement with custom exceptions.

# %% [markdown]
# ### 1. try and except

# %%
try:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print(a / b)
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# 0.04926108374384237

# %% [markdown]
# ### 2. Handling ValueError

# %%
try:
    age = int(input("Enter age: "))
    print("Age:", age)
except ValueError:
    print("Enter a valid number")
# Out:
# Age: 20

# %% [markdown]
# ### 3. try, except and else

# %%
try:
    a = int(input("Enter number: "))
    b = int(input("Enter number: "))
    result = a + b
except ValueError:
    print("Invalid input")
else:
    print("Sum:", result)
# Out:
# Sum: 134

# %% [markdown]
# ### 4. try, except, else and finally

# %%
try:
    a = int(input("Enter number: "))
    b = int(input("Enter number: "))
    print(a / b)
except ZeroDivisionError:
    print("Cannot divide by zero")
else:
    print("Division completed")
finally:
    print("Program finished")
# Out:
# 0.9701492537313433
# Division completed
# Program finished

# %% [markdown]
# ### 5. Multiple except Blocks

# %%
try:
    a = int(input("Enter number: "))
    b = int(input("Enter number: "))
    print(a / b)
except ValueError:
    print("Enter numbers only")
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# 1.3981337480559877

# %% [markdown]
# ### 6. raise Statement

# %%
age = 15

try:
    if age < 18:
        raise ValueError("Age must be 18 or above")
    print("Eligible")
except ValueError as e:
    print(e)
# Out:
# Age must be 18 or above

# %% [markdown]
# ### 7. Custom Exception

# %%
class AgeError(Exception):
    pass

age = 16

try:
    if age < 18:
        raise AgeError("Age is less than 18")
    print("Eligible")
except AgeError as e:
    print(e)
# Out:
# Age is less than 18

# %% [markdown]
# ### 8. Custom Exception with User Input

# %%
class MarksError(Exception):
    pass

marks = int(input("Enter marks: "))

try:
    if marks < 0 or marks > 100:
        raise MarksError("Marks should be between 0 and 100")
    print("Valid marks")
except MarksError as e:
    print(e)
# Out:
# Valid marks
